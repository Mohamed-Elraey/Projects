# %%
#List of largest corporate profits and losses from wikipedia

# %%
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://en.wikipedia.org/wiki/List_of_largest_corporate_profits_and_losses'

# %%
website = requests.get(url)

# %%
soup = BeautifulSoup(website.text, 'html')

# %%
#print(soup)

# %%
#soup.find_all('table')

# %%
#soup.find_all('table')[0]

# %%
required_table=soup.find_all('table')[0]

# %%
table_headers=required_table.find_all('th')

# %%
table_headers
# Out:
# [<th>#</th>,
#  <th>Company</th>,
#  <th>Industry</th>,
#  <th>Country</th>,
#  <th>Year</th>,
#  <th>Report date</th>,
#  <th>Earnings (billion)</th>,
#  <th>Earnings converted to USD and inflation adjusted (billion)
#  </th>]

# %%
table_headers_text = [header.text.strip() for header in table_headers]

# %%
table_headers_text
# Out:
# ['#',
#  'Company',
#  'Industry',
#  'Country',
#  'Year',
#  'Report date',
#  'Earnings (billion)',
#  'Earnings converted to USD and inflation adjusted (billion)']

# %%
import pandas as pd

# %%
df = pd.DataFrame(columns=table_headers_text)

# %%
df
# Out:
# Empty DataFrame
# Columns: [#, Company, Industry, Country, Year, Report date, Earnings (billion), Earnings converted to USD and inflation adjusted (billion)]
# Index: []

# %%
table_row = required_table.find_all('tr')

# %%
for row in table_row [1:]  :
    row_data = row.find_all('td')
    individual_row_data = [data.text.strip() for data in row_data]
    length = len(df)
    df.loc[length] = individual_row_data

# %%
df
# Out:
#      #                                Company                Industry  \
# 0    1                           Saudi Aramco             Oil and gas
# 1    2                           Saudi Aramco             Oil and gas
# 2    3                               Vodafone      Telecommunications
# 3    4                             Fannie Mae      Financial services
# 4    5                                  Apple    Consumer electronics
# 5    5                                  Apple    Consumer electronics
# 6    6                           Saudi Aramco             Oil and gas
# 7    7                     Berkshire Hathaway            Conglomerate
# 8    8                     Berkshire Hathaway            Conglomerate
# 9    9                           Saudi Aramco             Oil and gas
# 10  10                               Alphabet  Information technology
# 11  11                                  Apple    Consumer electronics
# 12  12                              Microsoft  Information technology
# 13  13                                  Apple    Consumer electronics
# 14  14                                  Apple    Consumer electronics
# 15  15                                  Apple    Consumer electronics
# 16  16                             ExxonMobil             Oil and gas
# 17  17  Industrial & Commercial Bank of China                 Banking
# 18  18  Industrial & Commercial Bank of China                 Banking
# 19  19                                  Apple    Consumer electronics
# 20  20                             ExxonMobil             Oil and gas
# 21  21                             ExxonMobil             Oil and gas
# 22  22                             ExxonMobil             Oil and gas
# 23  23                                  Apple    Consumer electronics
# 24  24                           Saudi Aramco             Oil and gas
# 25  25  Industrial & Commercial Bank of China                 Banking
# 26  26                             ExxonMobil             Oil and gas
# 27  27  Industrial & Commercial Bank of China                 Banking
# 28  28                     Berkshire Hathaway            Conglomerate
# 29  29                             ExxonMobil             Oil and gas
# 30  30                                  Apple    Consumer electronics
# 31  31  Industrial & Commercial Bank of China                 Banking
# 32  32  Industrial & Commercial Bank of China                 Banking
# 32            China  2017   31 December 2017    RMB 287.451[28]
# 33    United States  2021   31 December 2021         $48.33[29]
# 34            China  2019   31 December 2019    RMB 313.361[20]
# 35           Russia  2012   31 December 2012        RUB 1,224.5
# 36      Switzerland  2010   31 December 2010         $37.88[30]
# 37            China  2021   31 December 2021    RMB 303.928[31]
# 38            China  2018   31 December 2018    RMB 298.723[28]
# 39    United States  2020       30 June 2020         $44.28[32]
# 40            China  2016   31 December 2016    RMB 279.106[28]
# 41    United States  2014  27 September 2014         $39.51[33]
# 42    United States  2020   31 December 2020          $42.5[10]
# 43            China  2012   31 December 2012      RMB 238.7[34]
# 44    United States  2013  29 September 2013             $37.04
# 45            China  2014   31 December 2014    RMB 228.247[35]
# 46    United States  2020   31 December 2020          $40.7[11]
# 47            China  2020   31 December 2020    RMB 273.579[31]
# 48            China  2019   31 December 2019     RMB 255.63[31]
# 49    United States  2019       30 June 2019         $39.24[32]
# 50            China  2017   31 December 2017    RMB 243.615[36]
# 51  Netherlands  UK  2007   31 December 2007         $31.33[37]
# 52            China  2013   31 December 2013         RMB 214.65
# 53           Russia  2013   31 December 2013        RUB 1,139.2
# 54            China  2015   31 December 2015    RMB 228.886[35]
# 55            China  2018   31 December 2018    RMB 255.626[36]
#
#    Earnings converted to USD and inflation adjusted (billion)
# 0                                             $134.77
# 1                                             $129.47
# 2                                             $127.23
# 3                                             $109.85
# 4                                             $112.22
# 5                                             $106.46
# 6                                             $105.09
# 7                                             $100.97
# 8                                              $97.03
# 9                                              $94.27
# 10                                             $85.49
# 11                                             $72.23
# 12                                             $68.89
# 13                                             $68.64
# 14                                             $67.58
# 15                                             $65.85
# 16                                             $63.99
# 17                                             $60.75
# 18                                              $60.5
# 19                                              $60.1
# 20                                              $59.7
# 21                                             $59.67
# 22                                             $59.56
# 23                                             $58.02
# 24                                             $57.69
# 25                                             $57.79
# 26                                             $56.37
# 27                                              $56.2
# 28                                             $55.86
# 29                                             $55.61
# 30                                             $55.38
# 31                                                $55
# 32                                             $54.87
# 33                                             $54.35
# 34                                             $53.44
# 35                                             $53.31
# 36                                             $52.93
# 37                                             $52.72
# 38                                             $52.67
# 39                                             $52.13
# 40                                             $50.99
# 41                                             $50.85
# 42                                             $50.06
# 43                                             $50.16
# 44                                             $48.45
# 45                                             $47.74
# 46                                             $47.41
# 47                                             $46.27
# 48                                             $46.36
# 49                                             $46.76
# 50                                              $46.5
# 51                                             $46.04
# 52                                             $45.92
# 53                                             $45.43
# 54                                             $45.33
# 55                                             $45.09

# %%
df.to_csv(r'D:\Mohamed\Data science\Data analysis\PROJECTS\7- Wikipedia web scraping using python\wikipediaWebScraping.csv',index = False)
